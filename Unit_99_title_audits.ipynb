# %% [markdown]
# <a href="https://colab.research.google.com/github/tougheye/Data_processing/blob/main/Unit_99_title_audits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

folder_99_lists = "/content/drive/MyDrive/Data/Unit_99_Title_Claim/Historical 99 Data"

latest_99_file = pd.ExcelFile(f"{folder_99_lists}/UPTE_99_as_of_9_2_2026.xlsx")
latest_99_file.sheet_names
# Out:
# ['Report Page', 'Sheet1']

# %%
latest_99_df = latest_99_file.parse('Report Page')
latest_99_df.shape
# Out:
# (156877, 28)

# %%
second_latest_99_file = pd.ExcelFile(f"{folder_99_lists}/UPTE_99_as_of_6_3_2026.xlsx")
second_latest_99_file.sheet_names
# Out:
# ['Sheet1']

# %%
second_latest_99_df = second_latest_99_file.parse('Sheet1')
second_latest_99_df.shape
# Out:
# (172900, 25)

# %%
latest_job_titles_set = set(latest_99_df['Job Code Description'].unique())

# %%
second_latest_Job_titles_set = set(second_latest_99_df['Job Code Description'].unique())

# %%
latest_job_titles_set
# Out:
# {'CLIN ENGR 3',
#  'CUSTOMER SVC MGR 1',
#  'ACADEMIC COORD I-AY',
#  'Mechanical Staff Sci/Engr',
#  'HS ASSOC CLIN PROF-HCOMP',
#  'Mechnical Eng Tech Supervisor',
#  'VC AND DEAN SOM',
#  'FUNDRAISER 5',
#  'HEALTH EDUC MGR 1',
#  'ASSOC PROF IN RES-SFT-VM',
#  'CLIN PROF-VOL',
#  'Technical Support Superndt',
#  'DECISION SUPP SUPV 2',
#  'CIO MED CTR',
#  'DECISION SUPP MGR 1',
#  'INTERN-CLIN PSYCH-GEN CAMP NEX',
#  'Computational Sr Sci/Engr',
#  'Sr. Data Scientist',
#  'LABOR REL MGR 1',
#  'Energy/Env Policy Res Sci/Engr',
#  'NEURODIAGNOSTIC SVC MGR 1',
#  'EARLY CHILDHOOD EDUC SUPV 1',
#  'MANAGER',
#  'BUS DEV HC MGR 2',
#  'IC Design Engineer 3',
#  'ASSOC LIBRARIAN-CAREER NON REP',
#  'ACAD HR MGR 1',
#  'AST PHYSCN',
#  'BUS TCHL SUPP SUPV 2',
#  'STDT 1 WKSTY',
#  'IT ASSISTANT',
#  'MED STF SVC SUPV 1',
#  'INFO SYS ANL 3',
#  'Licensing Supervisor 1',
#  'SUPT MGR 3',
#  'ASSOC LAW LIBRARIAN',
#  'EMPLOYMENT REPR 3',
#  'ETHICS AND CMPLNC PROFL 2',
#  'BUS TCHL SUPP MGR 3',
#  'BEH HEALTH CNSLNG SUPV 2',
#  'Materials Sr Faculty Sci/Engr',
#  'PERFUSION MGR 1',
#  'Finance Mgr I, Property Mgmt',
#  'LECT-MISCELLANEOUS/PART TIME',
#  'ADMISSIONS EVALUATOR 3',
#  'EMPL DISABILITY SPEC 4',
#  'Earth Staff Scientist',
#  'BUS INTEL MGR 1',
#  'ACCESS AND ENGMT PROFL 3',
#  'Bioinformaticist Research SE',
#  'ACCESS AND ENGMT MGR 1',
#  'ADJ PROF-FY',
#  'STDT 3 WKSTY',
#  'PHYSCN NETWORK DEV SPEC 4',
#  'EH&S Manager 4',
#  'COACH AST 2',
#  'ACAD ACHIEVEMENT MGR 1',
#  'VISUAL COMM SPEC 4',
#  'Mathematician Sr Fac SE Shd',
#  'ASST PROJ SCI-FY NON REP',
#  'FINANCIAL ANL 4 CX',
#  'Emergency Management Spec. 4',
#  'EVENTS SPEC 5',
#  'STDT RSDNC HALLS LD',
#  'CARDIOVASCULAR SUPV 1',
#  'CENTER ASSOCIATE',
#  'NEURODIAGNOSTIC SVC SPEC 4',
#  'ADMIN AST 2',
#  'ABSOLUTE RETURNS INV DIR',
#  'MARKETING SPEC 2',
#  'RECORDS SUPV 2',
#  'STATE GOVT REL PROFL 5',
#  'PUBL EDUC SUPV 2',
#  'EXEC ASST TO THE C&D',
#  'ATH PROFL 2 BYA',
#  'STDT LIFE DEV MGR 1',
#  'SCRTY SUPV 1 HC',
#  'PAYROLL MGR 2',
#  'ASC VP CRO',
#  'ACCESS AND ENGMT PROFL 2',
#  'FIELD VETERINARIAN 3',
#  'FUNDRAISING HC MGR 4',
#  'ADJ PROF-FY-B/E/E',
#  'CONVERSION JOB CODE',
#  'VENDOR REL SPEC 2',
#  'MUSICIAN 4',
#  'Computational Sr Faculty SE',
#  'CLIN DOC SUPV 2',
#  'Physicist Senior Sci/Engr',
#  'STDT SVC SUPV 2 GF',
#  'MED STF SVC MGR 3',
#  'Electronic Research Sci/Engr',
#  'CUSTOMER SVC SUPV 1',
#  'STDT SVC MGR 2',
#  'FAC PROJECT MGR 1 HC',
#  'Supervisor, Admin Scvs',
#  'Computer Research Sci/Engr',
#  'ASST ADJ PROF-AY-B/E/E',
#  'BENEFITS MGR 1',
#  'COORD PUB PROG NON REP',
#  'OMBUDSPERSON 5',
#  'QLTY IMPV HC SPEC 5',
#  'RESID PHYS/SUBSPEC/T32/NON REP',
#  'READER-GSHIP',
#  'ADMISSIONS RECRMT MGR 2',
#  'ATH MGR 3 BYA',
#  'DECISION SUPP SPEC 3',
#  'REHAB SVC MGR 2',
#  'STDT CAMP PRG OFFSITE',
#  'AEROSPACE MGR 2',
#  'RAD THER MGR 3',
#  'Sr. Manager, Site Security',
#  'EHS SPEC 5',
#  'CLIN REGIS SUPV 2',
#  'FOOD SVC HC SUPV 2',
#  'ASSOC SPECIALIST NEX NON REP',
#  'Sr Web Developer',
#  'MEDIA COMM MGR 2',
#  'CLIN RSCH MGR 2',
#  'LABOR REL REPR 3',
#  'PGY2 SPEC POST PHARMD TRAINEE',
#  'AMBUL CARE PAT MGR 2',
#  'Occupational Health Pr Nurse',
#  'REIMB HC ANL 2',
#  'ASSOC SPECIALIST NON REP',
#  'INFO SYS MGR 2',
#  'BENEFITS PRG STRAT ANL 4',
#  'ACCOUNTING MGR 2 HC',
#  'PAT REL MGR 1',
#  'C Suite',
#  'WRITTEN COMM MGR 1',
#  'Computer Systems Engineer 5',
#  'STDT IT',
#  'LOAN ORIGINATION OFCR 2',
#  'MGN COUNSEL 3 HC',
#  'Division Deputy, Technology',
#  'ASST PROF-AY-B/E/E',
#  'PHYSCN DIPLOMATE SR',
#  'UNIV LIBRARIAN',
#  'COMM AND NETWORK TCHL SUPV 2',
#  'CMTY EDUC SPEC 2',
#  'ENTERPRISE RISK MGT ANL 3',
#  'LECTURER - 12 MONTH',
#  'PROCUREMENT SUPV 1',
#  'Facil Structural Engineer 4',
#  'CLIN IMG IT SPEC 2',
#  'STDT DISABILITY MGR 2',
#  'ACAD ACHIEVEMENT MGR 2',
#  'K TO 14 ACAD PREP MGR 1',
#  'HC ADM SHS MGR 2',
#  'RSCH CMPLNC SUPV 2 GF',
#  'MATERIALS MGT HC MGR 1',
#  'UTILIZATION MGT MGR 2',
#  'REIMB HC ANL 4 GF',
#  'RADLG SVC MGR 2',
#  'Pr Engineering Technical Assoc',
#  'Scientific Engineer',
#  'SUPPLY CHAIN MGR 4',
#  'RSCH GNT PRG OFCR 3',
#  'ACAD ACHIEVEMENT SUPV 2',
#  'REIMB HC MGR 1',
#  'PRODUCT DEV PROFL 4',
#  'EEO/Affirmative Action Anly II',
#  'CONTRACTS AND GRANTS SUPV 2 GF',
#  'INFO SYS ANL 3 GF',
#  'MATERIALS MGT HC SPEC 4',
#  'APPLICATIONS PROGR 3',
#  'ASSOC PROF IN RES-FY',
#  'HR Shared Service Spec',
#  'QLTY AND PERF METRICS ANL 3',
#  'Sr Supervisor, Admin Scvs',
#  'Area Deputy',
#  'IT SCRTY MGR 3',
#  'FUNDRAISING MGR 2',
#  'DIRECTOR OF ALUMNI',
#  'PROJECT POLICY ANL SUPV 2',
#  'QA CHEF 3',
#  'COMM HC MGR 4',
#  'MANAGING DIRECTOR',
#  'Facil Energy Mgmt Engineer 3',
#  'STDT SVC MGR 4',
#  'Electronics Engineer 2',
#  'Sr Finance Mgr, Procurement',
#  'ENTERPRISE RISK MGR 1',
#  'PHYSCN ADM 3',
#  'PROF IN RES-SFT-VM',
#  'Enterprise-wide Programmer Mgr',
#  'ORGANIZATIONAL CNSLT 4',
#  'Patent/Legal Counsel 4',
#  'DIR EXEC',
#  'ASST TEACHER-UNEX',
#  'COMM AND NETWORK TCHL MGR 2',
#  'PHYSCN NETWORK DEV SUPV 2',
#  'DATABASE ADM 3',
#  'REHAB SVC MGR 1',
#  'POPULATION HEALTH SPEC 4',
#  'Sr. Fin. Policy/Assur Spec',
#  'CLIN APPLICATIONS SUPV 2',
#  'CLIN REGIS SUPV 1',
#  'BLANK AST 2 SUPV',
#  'FINANCIAL AID MGR 3',
#  'ACAD ACHIEVEMENT CNSLR 5',
#  'CLIN INFORMATICS SUPV 2',
#  'Creative Services Manager 1',
#  'FUNDRAISER 2 NEX',
#  'CLIN PROFL SVC MGR 3',
#  'ASSOC COORD PUB PROG NON REP',
#  'INFO SYS SUPV 1',
#  'CLIN RSCH ANL 4',
#  'STDT 2 NON UC',
#  'POLICE LIEUTENANT MGR 1',
#  'RESP CARE MGR 2',
#  'ALUMNI EXTERNAL REL SPEC 4',
#  'EVENTS SPEC 1',
#  'Ind Contractor/Consultnt',
#  'GSR-FULL FEE REM',
#  'HEALTH EDUCATOR 4',
#  'Scientific Engineer Lead',
#  'Facil Energy Mgmt Engineer 4',
#  'Radiation Protection Spec 3',
#  'Recruitment Coordinator',
#  'PHYSCN NETWORK DEV SPEC 5',
#  'FINANCIAL AID OFCR 3',
#  'FUNDRAISING SUPV 1',
#  'EDUCATOR 3 BYA',
#  'Computational Biologist Fac SE',
#  'ENTERPRISE RISK MGT ANL 2',
#  'MED PHYSICS SUPV 2',
#  'NTRTN AND DIETARY HC SUPV 2',
#  'Electronics Eng Tech Manager',
#  'DIGITAL COMM SUPV 2',
#  'HS ASSOC CLIN PROF-AY',
#  'REVENUE CYCLE HC ANL 3',
#  'PUBL EDUC SPEC 5',
#  'BUS INTEL SPEC 2',
#  'Associate Web Developer',
#  'RSCH CMPLNC MGR 1',
#  'HEALTH PROFNS EDUC SPEC 5',
#  'Dept. Head, Internal Audit',
#  'Software Developer Supervisor',
#  'Policy Researcher I',
#  'ASST PROF IN RES-FY',
#  'Computer Staff Sci/Engr',
#  'COOP EXT ADVISOR',
#  'Geneticist Senior Sci/Engr',
#  'SYSWIDE ACAD HR MGR 3',
#  'Chief Laboratory Counsel',
#  'Sr Subcontracts Administrator',
#  'FACULTY CONSULTANT',
#  'CUSTODIAL HC SUPV 1 EX',
#  'REGISTRAR COLL SUPV 1',
#  'AEROSPACE ENGR 3',
#  'CTRL STERILE SUPV 1',
#  'K TO 12 EDUCATOR 5',
#  'ETHICS AND CMPLNC PROFL 1',
#  'TCHL PROJECT MGT PROFL 3',
#  'USER EXP DESIGNER SUPV 2',
#  'ENTERPRISE RISK MGT ANL 1',
#  'EXAMING PHYSCN',
#  'INDUSTRY ALLNS SUPV 2',
#  'Policy Researcher III',
#  'PROF OF TEACH-AY',
#  'Help Desk Specialist Trainee',
#  'Principal Conference Planner',
#  'ACT/INTERIM DEPARTMENT CHAIR',
#  'RECALL NON-FACULTY ACAD NEX',
#  'HEALTH INFO MGT MGR 3',
#  'STDT ACAD ADVISOR 4',
#  'FAC PROJECT MGT SPEC 5 HC',
#  'REHAB SVC SPEC 1',
#  'ATH MGR 2 BYA',
#  'ACADEMIC COORD III-AY',
#  'EMPLOYEE REL REPR 4',
#  'RES-LR SCL-AY-1/9-B/E/E',
#  'DATA SYS MGR 1',
#  'BIOINFORMATICS PROGR 3',
#  'VC INCLUSIVE EXCELLENCE',
#  'Project Planning & Controls 5',
#  'AGRON AES',
#  'GOVT REL MGR 3',
#  'CHF COMM OFCR ME',
#  'DOSIMETRY SUPV 2',
#  'CAREER SVC SPEC 3',
#  'BUS SYS ANL 3',
#  'HEALTH EDUCATOR 3 PD',
#  'ASST RES (WOS)',
#  'IT ARCHITECT 4',
#  'MUSEUM EDUC SUPV 1',
#  'PATHOLOGY AST 3',
#  'STDT LIFE DEVT SUPV 1',
#  'CLIN IMG IT SPEC 4',
#  'VENDOR REL MGR 1',
#  'SYS ADM 3',
#  'MGD CARE MGR 3',
#  'OMBUDSPERSON 3',
#  'PUBLICATIONS PROD SPEC 4',
#  'BEH HEALTH PSYCHIATRIC PROFL 4',
#  'ORGANIZATIONAL CNSLT 5',
#  'LOAN SVC ANL 4',
#  'Staff Web Developer',
#  'ACAD ACHIEVEMENT CNSLR 3',
#  'ACQUISITIONS EDITOR 4',
#  'K TO 14 ACAD PREP SUPV 1',
#  'CHILD LIFE MGR 2',
#  'PARKING OPS ENFORCEMENT SUPV 1',
#  'VETERINARIAN 3',
#  'HEALTH SCIENCES ADM 3',
#  'ACCOUNTING MGR 4 HC',
#  'BEH HEALTH PSYCHIATRIC MGR 1',
#  'FEDERAL GOVT REL PROFL 5',
#  'Occupational Safety Spec. 3',
#  'PHYSCN NETWORK DEV SPEC 3 GF',
#  'RECREATIONAL THER MGR 1',
#  'REHAB SVC SUPV 2',
#  'ANL 2',
#  'PROCUREMENT MGR 4',
#  'ASSOC RES-LR SCL-FY',
#  'Mechanical Engineer 3',
#  'FAC SUPV 1',
#  'PARKING AND TRANSPORT MGR 2',
#  'PROCUREMENT ANL 4',
#  'SPEAKER-UNEX',
#  'ADJ PROF-AY',
#  'EMPLOYMENT SUPV 1',
#  'Resident FVR',
#  'PROCUREMENT ANL 4 GF',
#  'ASC VP BUS OPS ANR',
#  'PAT SUPP SVC SUPV 2',
#  'EXECUTIVE DIRECTOR - HR',
#  'Chemical Faculty Engineer',
#  'Princ Business Systems Analyst',
#  'NEURODIAGNOSTIC SVC SUPV 2',
#  'INDUSTRY ALLNS MGR 3',
#  'FOOD SVC SUPV 2',
#  'CONCIERGE MGR 2',
#  'NURSE SVC MGR 1',
#  'Manager, IRSO',
#  'Computational Staff Sci/Engr',
#  'FUNDRAISER 1 NEX',
#  'CHF ADM OFCR SOM ME',
#  'TRANSPLANT MGR 2',
#  'PROF OF TEACH-HCOMP',
#  'SYSWIDE ACAD PERSONNEL ANL 3',
#  'TRAINER 3',
#  'MEDIA COMM MGR 3',
#  'CLIN NURSE OR ADV PRACT SPEC 4',
#  'Biologist Staff Sci/Engr',
#  'STDT LIFE DEV SPEC 3',
#  'EMPLOYEE REL MGR 3',
#  'ASST PROF-FY-B/E/E',
#  'PAYROLL ANL 5',
#  'PROJECT POLICY ANL SUPV 2 GF',
#  'EXEC AST 4',
#  'ASSOC PROF OF CLIN-SFT-VM',
#  'CONTRACTS AND GRANTS SUPV 2',
#  'Finance Mgr I, Accounting',
#  'DATA SYS SUPV 2',
#  'AMBUL CARE PAT SUPV 1',
#  'FINANCIAL ANL SUPV 1',
#  'MED STF SVC SPEC 4',
#  'ASSOC PROF TEACH-EMERITUS(WOS)',
#  'Sr Contracts Officer',
#  'ADMISSIONS RECRMT MGR 3',
#  'VETERINARIAN 4',
#  'STDT INTERN',
#  'REVENUE CYCLE HC MGR 2',
#  'IP MGR 4',
#  'VOC REHAB SUPV 2',
#  'Physicist Senior Fac SE Jt',
#  'FUNDRAISING SUPV 2',
#  'FEDERAL GOVT REL MGR 2',
#  'AGRON AES-AY',
#  'ACT/INTERIM ASSOC DIRECTOR',
#  'Division Deputy',
#  'PRES BENIOFF CHILDREN HOSP',
#  'Pr Resource Analyst',
#  'EVENTS SPEC 2',
#  'HS CLIN INSTR-HCOMP',
#  'ACUPUNCTURIST 3',
#  'Deputy Director',
#  'PROSPECT DEV MGR 2',
#  'Computational Biol Sr Fac SE',
#  'Occupational Safety Spec. 5',
#  'PUBL EQUITY INV ANL 3',
#  'Facil Structural Engineer 3',
#  'STDT INTERN NON UC',
#  'LIBRARY SUPV 2',
#  'Senior Compensation Analyst',
#  'Radiation Protection Spec 4',
#  'ASST PROF-FY',
#  'REVENUE CYCLE HC ANL 4',
#  'PARKING OPS ENFORCEMENT SUPV 2',
#  'VC IT CIO CAMPUS',
#  'ACAD PERSONNEL SUPV 2',
#  'FLEET SVC SUPV 1',
#  'CLIN NURSE EDUC 4',
#  'SYS ADM 4',
#  'FAC PROJECT MGT SPEC 2 HC',
#  'PAT REL SUPV 2',
#  'REAL ESTATE MGR 3',
#  'CLIN REGIS MGR 1',
#  'ADMIN MGR 1',
#  'BUS DEV HC PROFL 5',
#  'Strategic Communications Mgr 6',
#  'Business Manager 1',
#  'VC BUS ADMSTN',
#  'LABOR REL MGR 3',
#  'ASST ADJ PROF-SFT-VM',
#  'CHF MC ADM HC ME',
#  'STDT SVC ADVISOR 5',
#  'ANML CARE HOSP SUPV 1 VMTH',
#  'LABOR REL REPR 4',
#  'Communications Specialist 4',
#  'CMTY EDUC MGR 1',
#  'COMPENSATION ANL 5',
#  'REIMB HC ANL 1',
#  'Physicist Staff Sci/Engr',
#  'AUDIOLOGIST SR PD',
#  'ADJUNCT PROFESSOR',
#  'STDT 3',
#  'SYS ADMSTN SUPV 2',
#  'K TO 12 EDUCATOR MGR 2',
#  'DATA SYS ANL 5',
#  'MARKETING MGR 1',
#  'PROF IN RES-AY',
#  'ASSOC ADJ PROF-AY-1/10',
#  'BEH HEALTH CNSLNG SUPV 1',
#  'CMTY EDUC SPEC 3',
#  'GRADUATE FELLOW',
#  'EH&S Manager 1',
#  'Head of Contract & Strt Pship',
#  'Dept Head, L&OD',
#  'HEALTH INFO CODER 3',
#  'RISK MGT HC PROFL 4',
#  'AEROSPACE MGR 3',
#  'CARE Advocate',
#  'MEDIA COMM SUPV 2',
#  'FAC PROJECT MGT SPEC 4',
#  'COMM MGR 1',
#  'LABOR REL MGR 4',
#  'CHILD LIFE SUPV 2',
#  'ACT/INTERIM DIRECTOR',
#  'STDT RECR 2',
#  'ASSOC COLLEGE PROVOST',
#  'NTRTN AND DIETARY HC SUPV 1',
#  'ENERGY MGR 1',
#  'OMBUDSPERSON 4',
#  'REGISTRAR MGR 2',
#  'EXEC ADVISOR MGR 3',
#  'IP OFCR 3',
#  'TCHL PROJECT MGT PROFL 3 GF',
#  'VIS PROJ SCIENTIST',
#  'STDT SVC ADVISOR 3',
#  'K TO 12 EDUCATOR 2',
#  'COMM AND NETWORK TCHL ANL 4',
#  'MATERIALS MGT HC MGR 4',
#  'AVP EMPL AND LABOR RELATION ME',
#  'ETHICS AND CMPLNC MGR 1',
#  'REHAB SVC SUPV 1',
#  'Materials Faculty Sci/Engr',
#  'ASSOC AGRON AES-SFT-VM',
#  'DIRECTOR OF ACAD SUPPORT PGM',
#  'PLNG MGR 2',
#  'POLICE CAPTAIN MGR 2',
#  'ADMIN SUPV 1',
#  'DESIGN AND CONST HC MGR 3',
#  'PAT ACCESS SVC MGR 3',
#  'MED INTERPRETER SVC MGR 1',
#  'PROF-AY',
#  'CMTY EDUC SPEC 1',
#  'BUS SYS ANL MGR 3',
#  'ALUMNI EXTERNAL REL SPEC 1',
#  'ANL 5',
#  'POPULATION HEALTH MGR 3',
#  'LEGAL OPS MGR 1',
#  'Mechanical Eng Tech Manager',
#  'Radiation Protection Spec 5',
#  'VIS ASST RES NEX',
#  'Plant/Facil Engr Assoc',
#  'BEH HEALTH COUNSELOR 4',
#  'BUS DEV HC MGR 3',
#  'FINANCIAL SVC ANL 4 GF',
#  'Princ Data Scientist',
#  'Research Fellow',
#  'ACAD PRG MGT SUPV 2',
#  'QLTY IMPV HC MGR 2',
#  'Sr Fire Protection Eng Assoc',
#  'Facilities Technical Manager 1',
#  'REGISTRAR SPEC 4',
#  'STDT ACAD MGR 2',
#  'ACAD PRG MGT OFCR 5',
#  'CHF HR OFCR HC ME',
#  'PROJECT POLICY ANL 2',
#  'Mathematician Senior Sci/Engr',
#  'RSCH DATA ANL 3',
#  'Mechanical Engineer 2',
#  'STDT SVC SUPV 2',
#  'FINANCIAL SVC SUPV 2 GF',
#  'SYSWIDE BUDGET MGR 3',
#  'BUS INTEL SPEC 5',
#  'VOLUNTEER SVC PROFL 3',
#  'PROJECT POLICY ANL 4 GF',
#  'STDT LIFE DEVT SUPV 2 GF',
#  'ORGANIZATIONAL DEV MGR 3',
#  'Physicist Fac SE Shd',
#  'APPLICATIONS PROGR 2',
#  'Earth Sr Fac Scientist',
#  'FAC PROJECT MGT SPEC 5',
#  'QLTY IMPV HC SUPV 1',
#  'STRAT SOURCING MGR 3',
#  'APPLICATIONS PROGR 4',
#  'INFO SYS SUPV 2',
#  'LAB INSTRUCTION SUPV 1',
#  'DATA SYS ANL 4',
#  'EXEC AST 5',
#  'EVENTS CRD 3',
#  'PHARMACY MGR 1',
#  'ASSOC AGRON AES',
#  'HR MGR 3',
#  'VETERINARIAN 5',
#  'ADMIN OFCR 2',
#  'MGD CARE SUPV 2',
#  'HEALTH INFO MGT SUPV 1',
#  'BUS SYS ANL MGR 2',
#  'PROF EMERITUS(WOS)',
#  'Finance Mgr II, Accounting',
#  'COLLEGE PROVOST',
#  'Physicist Research Sci/Engr',
#  'ACT ASSOC PROF-AY',
#  'ADJ PROF-AY-1/9',
#  'AGRICULTURE MGR 1',
#  'CLIN APPLICATIONS MGR 4',
#  'FUNDRAISING MGR 3',
#  'CHF HR EXEC ME',
#  'CHF CAMPUS COUNSEL',
#  'PROJECT MGT PROFL 5',
#  'Mechanical Engineer 4',
#  'CONTRACT ADMSTN SUPV 1',
#  'PAT SUPP CALL CTR MGR 1',
#  'Affiliated Organization',
#  'MATERIALS MGT HC SUPV 2',
#  'CMPTL AND DATA SCI RSCH MGR 2',
#  'ANML CARE SUPV 2',
#  'Applied Physicist Sr Sci/Engr',
#  'VIS ASST SPECIALIST',
#  'HEALTH EDUCATOR 3',
#  'RSCH DATA ANL 1',
#  'FINANCIAL ANL MGR 2',
#  'LAUNDRY SUPV 1',
#  'EDUCATOR 2 BYA',
#  'Sr Scientific Engr Assoc',
#  'CMPTL AND DATA SCI RSCH SPEC 1',
#  'ASC VP CHF CLIN STRAT OFCR',
#  'HR MGR 4',
#  'TRANSPLANT MGR 1',
#  'PAT SFTY SUPV 2',
#  'Biological Faculty Engineer',
#  'BUS TCHL SUPP MGR 1',
#  'MED STF SVC MGR 2',
#  'EMPLOYEE REL REPR 1',
#  'ASSOC COOP EXT ADVISOR',
#  'VISUAL COMM MGR 1',
#  'VOLUNTEER SVC PROFL 4',
#  'Construction Worker II',
#  'PROF-FY',
#  'ASST PROF OF TEACH-AY-1/9',
#  'ADVOCATE 4',
#  'TRAINER 2',
#  'Finance Mgr I, Financial Analy',
#  'SVP EXTERNAL  REL AND COMM',
#  'CLIN LAB SHS SUPV 2',
#  'EMPLOYEE REL MGR 1',
#  'ASST ADJ PROF-AY-1/9',
#  'ADVOCACY MGR 1',
#  'WRITER EDITOR 4',
#  'INSTRUCTIONAL DESIGNER 5',
#  'PROJ SCI-FY-B/E/E NON REP',
#  'BENEFITS PRG STRAT MGR 3',
#  'PHARMACY MGR 4',
#  'FUNDRAISER 3 GF',
#  'CLIN APPLICATIONS PROFL 5',
#  'HEALTH PROFNS EDUC MGR 2',
#  'AUDIT PROFL 3',
#  'PLNG MGR 1',
#  'IP OFCR 4',
#  'CLIN NURSE SHS MGR 1',
#  'TREASURY MGR 2',
#  'EEO REPR 2',
#  'Staff Web Content Administrato',
#  'ASST PROF OF TEACH-AY',
#  'POPULATION HEALTH SPEC 3 GF',
#  'SYSWIDE ACAD PERSONNEL ANL 5',
#  'BUS SYS ANL 3 GF',
#  'Sr Systems Administrator',
#  'GENERAL SVC OTHER SUPV 1',
#  'PROJECT POLICY ANL MGR 1',
#  'PAT SFTY PROFL 2',
#  'ADV PRACTICE MGR 2',
#  'REVENUE CYCLE HC ANL 2',
#  'VIS RES NEX',
#  'MARKETING SPEC 4',
#  'ADMIN MGR 2',
#  'VENDOR REL SPEC 4',
#  'AGRON AES-B/E/E-AY',
#  'VENDOR REL SUPV 2',
#  'AGRON AES-SFT-VM',
#  'SEA CAPTAIN MGR 2',
#  'ASSOC PROF OF TEACH-AY',
#  'INFO SYS ANL 5',
#  'LEGAL SUPP SPEC 4',
#  'K-12 DAILY SUBSTITUTE/NONREP',
#  'Export Compliance Specialist 3',
#  'EMBRYOLOGIST 3',
#  'MEDIA COMM SPEC 2',
#  'OTH POST-MD TRAIN 2-8/NON REP',
#  'HR AST 3',
#  'Compl Biologist Res Sci/Engr',
#  'EDUCATOR (WOS)',
#  'CUSTODIAL SUPV 2',
#  'Pr Accountant',
#  'RESP CARE SUPV 1',
#  'QLTY AND PERF METRICS ANL 4',
#  'Earth Faculty Scientist',
#  'DEPUTY GEN COUNSEL',
#  'EVP COO',
#  'EMPLOYEE REL REPR 2',
#  'RISK MGT HC PROFL 3',
#  'STDT RSDNC HALLS',
#  'REAL ESTATE OFCR 5',
#  'Senior Advisor',
#  'REGISTRAR SUPV 1',
#  'ASSISTANT DEAN (STAFF)',
#  'LAB PROCESSING SUPV 2',
#  'EMPLOYMENT MGR 1',
#  'NEURODIAGNOSTIC SVC SPEC 5',
#  'COMM SPEC 4',
#  'Computer Faculty Sci/Engr',
#  'DEPARTMENT VICE CHAIR',
#  'CUSTODIAL MGR 2',
#  'EVENTS MGR 1',
#  'ATH MGR 4 BYA',
#  'ANML CARE MGR 4',
#  'TEACHER-UNEX',
#  'ASSOC FLD PROG SUPV',
#  'AMBUL CARE ADMSTN CRD 5',
#  'Facil Electrical Engineer 4',
#  'COMPENSATION MGR 1',
#  'CHAN',
#  'ACAD PERSONNEL MGR 3',
#  'MUSEUM EDUC MGR 1',
#  'Post Baccalaureate Fellow',
#  'CHF REAL ESTATE OFCR ME',
#  'Electronics Engineer 3',
#  'Associate Data Scientist',
#  'CLIN IMG IT SUPV 2',
#  'ADJ PROF-AY-1/10-BEE',
#  'PRES SVP CHF MARKET DEV',
#  'Truck Driver Lead',
#  'Regulatory Compl Eng/Spec 4',
#  'DESIGN AND CONST MGT SPEC 2',
#  'Mechanical Faculty Sci/Engr',
#  'Lab Project Management Officer',
#  'REVENUE CYCLE HC MGR 3',
#  'ASSOC RES-LR SCL-AY-1/9',
#  'ASC VP CAP PRG SUSTAIN',
#  'ADMISSIONS RECRMT SUPV 1',
#  'EEO REPR 3',
#  'TCHL PROJECT MGT PROFL 2',
#  'BENEFITS ANL 1',
#  'Waste Mgmt Professional 2',
#  'LOAN ORIGINATION MGR 2',
#  'BUS DEV PROFL 3',
#  'AV IT ENGR 4',
#  'Finance Mgr II, Procurement',
#  'ACADEMIC ADMINISTRATOR II',
#  'FACULTY ADVISOR',
#  'ASST PROF-SFT-VM',
#  'EXEC AST 3',
#  'ANATOMICAL SVC PROFL 4',
#  'MUSEUM EDUCATOR 3',
#  'Sr Financial Analyst',
#  'RECALL HCOMP',
#  'RES-FY-B/E/E NEX NON REP',
#  'PAT BILL AND COLL MGR 2',
#  'VIS RES',
#  'STDT SVC MGR 3',
#  'ADMIN AST 1',
#  'Biological Engineer Senior Sci',
#  'BUS TCHL SUPP SUPV 1',
#  'SUSTAIN OFCR 5',
#  'CONTRACT ADMSTN MGR 2',
#  'FAC MGT SPEC 2',
#  'POLICE OFCR 1',
#  'RECR PRG INSTR',
#  'PAT SFTY PROFL 5',
#  'ADMISSIONS RECRMT SPEC 3',
#  'CLIN ENGR MGR 1',
#  'Facilities Technical Manager 4',
#  'COMM MGR 4',
#  'HEALTH EDUC SUPV 1',
#  'VIS JR SPECIALIST',
#  'Facilities Architect 4',
#  'ASST ADJ PROF-FY-B/E/E',
#  'TAX CMPLNC SUPV 1',
#  'CLIN IMG IT SPEC 3',
#  'MARKETING SPEC 5',
#  'BEH HEALTH PSYCHIATRIC MGR 2',
#  'IP OFCR 2',
#  'STDT 1 NON UC',
#  'RECR PRG LEADER 2',
#  'ASC VP BUDGET ANL PLNG',
#  'Construction Safety Spec. 3',
#  'Sr EH&S Professional',
#  'STRAT SOURCING PROFL 4',
#  'CLIN PROFL SVC MGR 2',
#  'ACAD PRG MGT OFCR 4',
#  'CASE MGT HC SUPV 2',
#  'ASSOCIATE PROFESSOR OF LAW',
#  'PHYSCN SHS MGR 2',
#  'ACT/INTERIM ASSOC VICE CHANC',
#  'MAIL SVC MGR 1',
#  'RSCH ADM 4',
#  'ETHICS AND CMPLNC PROFL 5',
#  'HR Division Partner II',
#  'PAT ACCESS SVC SUPV 2',
#  'INFO SYS HC MGR 3',
#  'FAC MGR 1',
#  'PROVIDER ENROLLMENT PROFL 3',
#  'TREASURY ANL 2',
#  'Resident, LAK',
#  'STDT INTRA SPORTS 1',
#  'RESID PHYS I/NON REP',
#  'REVENUE CYCLE HC MGR 1',
#  'Research Associate',
#  'COO INV SVC OCIO',
#  'Pr Subcontracts Administrator',
#  'RSCH CMPLNC ANL 3',
#  'CMPTL AND DATA SCI RSCH MGR 1',
#  'RESID-VET MED/NON REP',
#  'EHS SPEC 4',
#  'Electronics Engineer 4',
#  'CMTY EDUC SUPV 2',
#  'PROD CNTRL ANL 2',
#  'TAX CMPLNC MGR 2',
#  'HR Manager II, HR Systems',
#  'ACADEMIC COORD II-FY',
#  'PAYROLL ANL 3',
#  'ASSOC PROJ SCIENTIST (WOS)',
#  'NURSE PRAC RSDT',
#  'CONTRACT ADMSTN MGR 1',
#  'CLIN INSTR-VOL',
#  'Communications Specialist 1',
#  'BUS TCHL SUPP MGR 2',
#  'Program Manager 4',
#  'Regulatory Compl Eng/Spec 2',
#  'ASSOC PROF IN RES-AY-B/E/E',
#  'ASSOC SPECIALIST (WOS)',
#  'PROF OF CLIN-FY',
#  'PROJECT MGT PROFL 4',
#  'FINANCIAL SVC ANL 4',
#  'CLIN INFORMATICS MGR 1',
#  'ADV PRACTICE MGR 3',
#  'IT SCRTY MGR 2',
#  'CHANCELLOR AND DEAN',
#  'BUS INTEL MGR 3',
#  'ACAD PERSONNEL MGR 1',
#  'PROF-FY-B/E/E',
#  'PAT SUPP SVC MGR 1',
#  'PAT REL MGR 3',
#  'ASSOC RES-LR SCL-AY-1/9-B/E/E',
#  'RSDT ADVISOR 2',
#  'SENIOR CAREER COUNSELOR',
#  'RISK MGT HC PROFL 3 GF',
#  'ASSOC PROF-AY-1/9-B/E/E',
#  'INSTRUCTIONAL DESIGN MGR 1',
#  'ACADEMIC COORD II-FY NEX',
#  'AEROSPACE MGR 1',
#  'VC AND DEAN MARINE SCI',
#  'ORGANIZATIONAL CNSLT 3',
#  'CAMP CNSLR L3',
#  'THEATER PROD SPEC 3',
#  'SULLIVAN PROFESSOR OF LAW',
#  'BUS DEV HC MGR 1',
#  'K TO 12 EDUCATOR 4',
#  'TCHL PROJECT MGT PROFL 1',
#  'Biophysicist Staff Sci/Engr',
#  'PHYSCN NETWORK DEV MGR 1',
#  'ACAD HR ANL 1',
#  'SHIP SCHEDULER 3',
#  'ACADEMIC COORD III-FY NEX',
#  'Office/Administrative Manager',
#  'ETHICS AND CMPLNC PROFL 3',
#  'PARKING OPS SPEC 2',
#  'BUS INTEL SUPV 2',
#  'CLIN RSCH MGR 3',
#  'DIRECTOR OF DRP',
#  'Project Planning & Controls 4',
#  'STRAT SOURCING MGR 2',
#  'SURVEY RESEARCHER SUPV 1',
#  'CAREER SVC SUPV 1',
#  'MASSAGE THERAPIST 2',
#  'RADLG SVC SUPV 1',
#  'Earth Sr Fac Scientist Shd',
#  'Sr Plant/Facil Engr Assoc',
#  'PROFL ENGR MGR 2',
#  'LOAN ORIGINATION OFCR 4',
#  'LIBRARIAN-CAREER NON REP',
#  'EXEC VC AND PROVOST',
#  'Business Manager 2',
#  'Biophysicist Research Sci/Engr',
#  'TCHL PROJECT SUPV 2',
#  'CHARGE DESC ANL 4 GF',
#  'REAL ESTATE OFCR 4',
#  'PLNG SPEC 4',
#  'ASC VP HS',
#  'FLD PROG SUPV',
#  'PAT CASHIERING SUPV 1 NEX',
#  'RISK MGT HC PROFL 5',
#  'RISK MGT HC PROFL 2',
#  'PRIVACY AND CMPLNC HC PROFL 4',
#  'RECR MGR 2',
#  'Training Specialist 3',
#  'PHARMACY SHS MGR 1',
#  'FAC PROJECT MGT SPEC 3 HC',
#  'EMPL DISABILITY SPEC 3',
#  'Grad Student - Non GSRA',
#  'PUBLICATIONS PROD SPEC 3',
#  'Facil Mechanical Engineer 3',
#  'GRADUATE RESEARCH FELLOW',
#  'AUDIT PROFL 2',
#  'PAT BILLER 3',
#  'RSCH AND DEV ENGR 2',
#  'Chemist Senior Sci/Engr',
#  'CAPITAL MARKETS FIN OFCR 5',
#  'PROF-AY-LAW',
#  'HR GENERALIST 4',
#  'PUBL EDUC SUPV 1',
#  'SPORTS MED ATH TRAINER SUPV 2',
#  'CLIN APPLICATIONS PROFL 3',
#  'EHS MGR 4',
#  'CONCIERGE 4',
#  'RSCH DATA ANL 5',
#  'CHILD LIFE MGR 1',
#  'LEAVE OF ABSENCE SPEC 3',
#  'CARDIOVASCULAR SUPV 2',
#  'Systems Administrator',
#  'VP-SWHR/SWSS',
#  'ADMISSIONS RECRMT MGR 1',
#  'PRIVACY AND CMPLNC HC PROFL 3',
#  'Biochemist Research Sci/Engr',
#  'PROCUREMENT ANL 3',
#  'Staff Volunteer',
#  'POPULATION HEALTH SPEC 5',
#  'CWSP-ON CAMPUS',
#  'Project Manager 2',
#  'ANL 6',
#  'EMBRYOLOGIST 5',
#  'PERF ARTS MGR 1',
#  'ASSOC PROF IN RES-FY-B/E/E',
#  'RECORDS ANL 4',
#  'CURATORIAL SUPV 2',
#  'ASSOC PROF OF CLIN-HCOMP',
#  'CLIN NURSE EDUC 5',
#  'Chemist Staff Sci/Engr',
#  'Waste Mgmt Professional 4',
#  'CLIN PROFL SVC MGR 4',
#  'Materials Sr Fac SE Jt',
#  'REGISTRAR MGR 1',
#  'ASSOC PROF OF TEACH-HCOMP',
#  'ACAD PERSONNEL ANL 2',
#  'COMM AND NETWORK TCHL MGR 3',
#  'RESID PHYS/SUBSPEC 4-8/NON REP',
#  'SKLD CRAFTS TRADES MGR 1',
#  'Sr Resource Analyst',
#  'CTRL STERILE MGR 1',
#  'DEPUTY FIRE CHF MGR 2',
#  'ADMIN ANL PRN 1',
#  'FIELD VETERINARIAN 2',
#  'ASSOC PROF-HCOMP',
#  'ADMISSIONS RECRMT SPEC 4',
#  'IT SCRTY ANL 5',
#  'POLICE SVC SUPV 2',
#  'ACADEMIC DEAN',
#  'COACH AST 3',
#  'Program Operations Analyst 2',
#  'REGL POLICY AND INTEL PROFL 4',
#  'Lead Accountant',
#  'MATERIALS MGT HC SPEC 3',
#  'EXEC ADVISOR MGR 1',
#  'CLIN NURSE SHS SUPV 2',
#  'CENTER SENIOR ASSOCIATE',
#  'GOVT REL SPEC 5',
#  'Biophysicist Senior Faculty SE',
#  'MAIL SVC SUPV 1',
#  'ANML CARE MGR 2',
#  'DIETITIAN HC SPEC 4',
#  'DATA ANALYSIS SUPV 2',
#  'ENERGY MGT ANL 4',
#  'ASST RES-FY-NON REP',
#  'Communications Specialist 5',
#  'EEO REPR 4',
#  'IT ARCHITECT MGR 3',
#  'EXEC ADVISOR 3',
#  'Technology Researcher III',
#  'ACADEMIC ADMINISTRATOR VII',
#  'SYSWIDE ACAD PERSONNEL ANL 4',
#  'RECR COACH 3',
#  'POPULATION HEALTH MGR 2',
#  'K TO 14 ACAD PREP SPEC 4',
#  'CMTY HEALTH OUTR MGR 1',
#  'CUSTODIAL MGR 1',
#  'SYSWIDE BUDGET ANL 4',
#  'QLTY IMPV HC SPEC 4',
#  'GOVT REL MGR 1',
#  'RSCH GNT PRG MGR 1',
#  'LECTURER - 9 MONTH',
#  'FINANCIAL SVC SUPV 2',
#  'LOAN ORIGINATION OFCR 3',
#  'FINANCIAL SVC ANL 3',
#  'Student Assistant',
#  'Materials Fac SE Shd',
#  'ASST SPECIALIST (WOS)',
#  'COURSE AUTHOR-UNEX',
#  'HS CLIN PROF-HCOMP',
#  'CMPTL AND DATA SCI RSCH MGR 3',
#  'Animal Care Unit Mgr (Non/DVM)',
#  'NTRTN AND DIETARY HC MGR 1',
#  'PLNG SPEC 2',
#  'ASSOC VICE PROVOST',
#  'CONTRACT ADMSTN SUPV 2',
#  'ANML CARE MGR 1',
#  'RES-FY-NON REP',
#  'CONTRACTS AND GRANTS MGR 1',
#  'HEALTH PROFNS EDUC SPEC 4 GF',
#  'CHF INFO OFCR CAMPUS ME',
#  'PROCUREMENT ANL 5',
#  'ASC VP CLIN AFF CHO',
#  'CURRICULUM PLNR 4',
#  'FIELD RSCH MGR 1',
#  'CMTY EDUC SPEC 4',
#  'PRIVACY AND CMPLNC HC MGR 2',
#  'Compensation Analyst II',
#  'AUDIT MGR 4',
#  'ASSOCIATE DIRECTOR (MGMT)',
#  'STDT PHARMACY INTERN',
#  'Data Science Supervisor',
#  'SUPPLY CHAIN MGR 3',
#  'PAT REL SUPV 1',
#  'PUBL EDUC MGR 1',
#  'Program Operations Analyst 3',
#  'FOOD SVC MGR 2',
#  'AFFILIATED SCHOLAR',
#  'ACAD HR MGR 3',
#  'ALUMNI EXTERNAL REL MGR 1',
#  'Fire Protection Eng Assoc',
#  'Work Planning & Control Spec 5',
#  'ASST PROJ SCIENTIST-FY',
#  'CLIN ENGR SUPV 1',
#  'TREASURY ANL 5',
#  'CLIN NURSE EDUC MGR 2',
#  'PUBL EQUITY INV OFCR',
#  'HEALTH INFO CODER 4',
#  'I&E EQUITY ANL 5',
#  'QA RELEASE MGT ANL 4',
#  'CLIN INFORMATICS MGR 2',
#  'CUSTODIAL HC MGR 2',
#  'Work Planning & Control Spec 3',
#  'IP OFCR 1',
#  'PAT BILL AND COLL SUPV 1',
#  'Pr Financial Analyst',
#  'DENTIST AST',
#  'RECALLED PROFESSOR OF LAW',
#  'EHS SPEC 2 NEX',
#  'CLIN REGIS ANL 3',
#  'REHAB SVC SPEC 4',
#  'RSCH CMPLNC ANL 4 GF',
#  'ASSOC AGRON AES-B/E/E',
#  'SUPPLY CHAIN MGR 2',
#  'Elec Eng Tech Superintendent',
#  'HC ADM SHS MGR 3',
#  'COMM SPEC 3',
#  'Writer/Editor 2',
#  'ATH TRAINING MGR 1',
#  'ATH TRAINER 3',
#  'PAT NAVGTR NON-CLIN SUPV 2',
#  'INSTITUTIONAL RSCH ANL 1',
#  'FINANCIAL SVC MGR 4',
#  'Chemist Research Sci/Engr',
#  'MED STF SVC SPEC 2',
#  'Licensing Associate',
#  'REIMB HC ANL 4',
#  'PROJECT POLICY ANL 3',
#  'PROF-AY-B/E/E',
#  'Desktop Systems Supervisor',
#  'CHI GREEN SCHOLAR-UCSD',
#  'IC Design Staff Sci/Engr',
#  'Occ Health Clinic Manager (RN)',
#  'Finance Mgr I, Resource Mgmt',
#  'HR GENERALIST 1',
#  'PROD CNTRL ANL 3',
#  ...}
