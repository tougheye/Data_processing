# %% [markdown]
# <a href="https://colab.research.google.com/github/tougheye/Data_processing/blob/main/IT_External_Addr_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

full_it_df = pd.read_excel("/content/External IT Statewide Addresses.xlsx")
full_it_df.shape
# Out:
# (4732, 10)
